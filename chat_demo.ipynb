# %% [markdown]
# <a href="https://colab.research.google.com/github/michael-borck/michael-borck/blob/main/chat_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install hands-on-ai

# %%
import os

# Configure your provider
os.environ['HANDS_ON_AI_SERVER'] = 'https://ollama.serveur.au'
os.environ['HANDS_ON_AI_MODEL'] = 'llama3.2'
os.environ['HANDS_ON_AI_API_KEY'] = input('Enter your API key: ')

# %%
from hands_on_ai.chat import pirate_bot

# Ask the pirate bot a question
response = pirate_bot("What is photosynthesis?")
print(response)
